# %%
import pandas as pd

# %%
trade_df = pd.read_csv('../data/total_trade.csv', encoding='utf-8-sig')
trade_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기간      687 non-null    object
#  1   국가      687 non-null    object
#  2   HS코드    687 non-null    float64
#  3   품목명     687 non-null    object
#  4   수출 중량   687 non-null    int64
#  5   수출 금액   687 non-null    int64
#  6   수입 중량   687 non-null    int64
#  7   수입 금액   687 non-null    int64
#  8   무역수지    687 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 48.4+ KB

# %%
# 무역 데이터 상위 5개 행 확인
trade_df.head()

# %%
# 무역 데이터 기초 통계량 확인
trade_df.describe()

# %%
# reuter 뉴스 데이터 불러오기
reuter_df = pd.read_csv('../data/reuters.csv', encoding='utf-8-sig')
reuter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37172 entries, 0 to 37171
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        37172 non-null  object
#  1   date       37172 non-null  object
#  2   title      37172 non-null  object
#  3   main_text  37161 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB

# %%
# 뉴스 데이터 상위 5개 행 확인
reuter_df.head()
# Out:
#                                                  url                 date  \
# 0  https://www.reuters.com/breakingviews/abrdn-an...  2024-01-24 12:58:24
# 1  https://www.reuters.com/breakingviews/abu-dhab...  2024-01-26 07:02:43
# 2  https://www.reuters.com/breakingviews/adani-is...  2024-02-14 03:52:25
# 3  https://www.reuters.com/breakingviews/ai-start...  2024-01-09 15:28:49
# 4  https://www.reuters.com/breakingviews/ai-will-...  2024-05-30 12:46:05
#
#                                                title  \
# 0             Abrdn anguish has no clear M&A endgame
# 1     Abu Dhabi’s Europe M&A hedges an opaque future
# 2           Adani is a gift that will keep on giving
# 3  AI startups’ key challenge is creativity, not ...
# 4  AI will power up buyout barons’ green-energy s...
#
#                                            main_text
# 0  (The author is a Reuters Breakingviews columni...
# 1  LONDON, Jan 26 (Reuters Breakingviews) - Sulta...
# ...

# %%
# 뉴스 데이터 기초 통계량 확인
reuter_df.describe()

# %%
#BBC
bbc_df = pd.read_csv('../data/BBC_title.csv', encoding='utf-8-sig')
bbc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024 entries, 0 to 3023
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  3024 non-null   object
#  1   Headline              2876 non-null   object
#  2   Source                3024 non-null   object
#  3   Market_Event          3024 non-null   object
#  4   Market_Index          3024 non-null   object
#  5   Index_Change_Percent  2863 non-null   float64
#  6   Trading_Volume        3024 non-null   float64
#  7   Sentiment             2853 non-null   object
#  8   Sector                3024 non-null   object
#  9   Impact_Level          3024 non-null   object
#  10  Related_Company       3024 non-null   object
#  11  News_Url              2871 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 283.6+ KB

# %%
#acled
acled_df = pd.read_csv('../data/ACLED_data.csv', encoding='utf-8-sig')
acled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44686 entries, 0 to 44685
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   event_id_cnty       44686 non-null  object
#  1   event_date          44686 non-null  object
#  2   year                44686 non-null  int64
#  3   time_precision      44686 non-null  int64
#  4   disorder_type       44686 non-null  object
#  5   event_type          44686 non-null  object
#  6   sub_event_type      44686 non-null  object
#  7   actor1              44686 non-null  object
#  8   assoc_actor_1       32046 non-null  object
#  9   inter1              44686 non-null  object
#  10  actor2              2377 non-null   object
#  11  assoc_actor_2       1097 non-null   object
#  12  inter2              2377 non-null   object
#  13  interaction         44686 non-null  object
#  14  civilian_targeting  997 non-null    object
# ...

# %%
acled_df.head()
# Out:
#   event_id_cnty  event_date  year  time_precision   disorder_type event_type  \
# 0       CHN9323  2021-01-01  2021               1  Demonstrations   Protests
# 1       CHN9328  2021-01-01  2021               1  Demonstrations   Protests
# 2       CHN9327  2021-01-01  2021               1  Demonstrations   Protests
# 3       CHN9324  2021-01-01  2021               1  Demonstrations   Protests
# 4       CHN9325  2021-01-01  2021               1  Demonstrations   Protests
#
#      sub_event_type              actor1  \
# 0  Peaceful protest  Protesters (China)
# 1  Peaceful protest  Protesters (China)
# 2  Peaceful protest  Protesters (China)
# 3  Peaceful protest  Protesters (China)
# 4  Peaceful protest  Protesters (China)
#
#                                        assoc_actor_1      inter1  ...  \
# 0  Government of China (2017-) Hong Kong Special ...  Protesters  ...
# 1  ADPL: Hong Kong Association for Democracy and ...  Protesters  ...
# ...
